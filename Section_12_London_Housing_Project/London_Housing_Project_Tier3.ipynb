# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
#Prints out 1st 5 rows of properties Dataframe
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
#Prints concise summary of properties Dataframe
#Prints information about properties DataFrame including the index dtype and columns, non-null values and memory usage.
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            334 non-null    datetime64[ns]
#  1   City of London        335 non-null    object
#  2   Barking & Dagenham    335 non-null    object
#  3   Barnet                335 non-null    object
#  4   Bexley                335 non-null    object
#  5   Brent                 335 non-null    object
#  6   Bromley               335 non-null    object
#  7   Camden                335 non-null    object
#  8   Croydon               335 non-null    object
#  9   Ealing                335 non-null    object
#  10  Enfield               335 non-null    object
#  11  Greenwich             335 non-null    object
#  12  Hackney               335 non-null    object
#  13  Hammersmith & Fulham  335 non-null    object
# ...

# %%
#Returns tuple containing number of rows, number of columns in properties Dataframe
properties.shape
# Out:
# (335, 49)

# %%
#Prints summary statistics of properties Dataframe
#By default .describe() only will summarize columns containing data of numeric type, include = 'all' will describe all columns, regardless of data type
properties.describe(include = 'all', datetime_is_numeric = True)
# Out:
#                            Unnamed: 0 City of London Barking & Dagenham  \
# count                             334            335                335
# unique                            NaN            335                335
# top                               NaN      E09000001          E09000002
# freq                              NaN              1                  1
# mean    2008-11-15 06:28:01.437125632            NaN                NaN
# min               1995-01-01 00:00:00            NaN                NaN
# 25%               2001-12-08 18:00:00            NaN                NaN
# 50%               2008-11-16 00:00:00            NaN                NaN
# 75%               2015-10-24 06:00:00            NaN                NaN
# max               2022-10-01 00:00:00            NaN                NaN
# std                               NaN            NaN                NaN
#
#            Barnet     Bexley      Brent    Bromley     Camden    Croydon  \
# ...

# %%
#Prints column labels of a Dataframe
properties.columns
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
#Prints indexing of properties Dataframe 
properties.index
# Out:
# RangeIndex(start=0, stop=335, step=1)

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
#Converting dates to year-month
properties['Unnamed: 0'] = properties['Unnamed: 0'].dt.strftime('%Y-%m')
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaN      E09000001          E09000002    E09000003    E09000004
# 1    1995-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2    1995-02    82202.77314        51085.77983  93190.16963  64787.92069
# 3    1995-03    79120.70256        51268.96956  92247.52435  64367.49344
# 4    1995-04    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
#Transpose properties Dataframe
properties = properties.transpose()
properties.head()
# Out:
#                           0            1            2            3    \
# Unnamed: 0                NaN      1995-01      1995-02      1995-03
# City of London      E09000001  91448.98487  82202.77314  79120.70256
# Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# Barnet              E09000003  93284.51832  93190.16963  92247.52435
# Bexley              E09000004  64958.09036  64787.92069  64367.49344
#
#                             4            5            6            7    \
# Unnamed: 0              1995-04      1995-05      1995-06      1995-07
# City of London      77101.20804  84409.14932  94900.51244  110128.0423
# Barking & Dagenham  53133.50526  53042.24852  53700.34831  52113.12157
# Barnet              90762.87492  90258.00033  90107.23471  91441.24768
# Bexley              64277.66881  63997.13588  64252.32335  63722.70055
#
#                             8            9    ...           325           326  \
# ...

# %%
#Checking index of transposed properties
properties.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
#Reseting index
properties = properties.reset_index()
properties.head()
# Out:
#                 index          0            1            2            3  \
# 0          Unnamed: 0        NaN      1995-01      1995-02      1995-03
# 1      City of London  E09000001  91448.98487  82202.77314  79120.70256
# 2  Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# 3              Barnet  E09000003  93284.51832  93190.16963  92247.52435
# 4              Bexley  E09000004  64958.09036  64787.92069  64367.49344
#
#              4            5            6            7            8  ...  \
# 0      1995-04      1995-05      1995-06      1995-07      1995-08  ...
# 1  77101.20804  84409.14932  94900.51244  110128.0423  112329.4376  ...
# 2  53133.50526  53042.24852  53700.34831  52113.12157  52232.19868  ...
# 3  90762.87492  90258.00033  90107.23471  91441.24768  92361.31512  ...
# 4  64277.66881  63997.13588  64252.32335  63722.70055  64432.60005  ...
#
#             325           326           327           328           329  \
# ...

# %%
#Checking indices are integers
properties.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
#Replacing 1st row values to column headers
properties.columns = properties.iloc[0]
properties.head()
# Out:
# 0          Unnamed: 0        NaN      1995-01      1995-02      1995-03  \
# 0          Unnamed: 0        NaN      1995-01      1995-02      1995-03
# 1      City of London  E09000001  91448.98487  82202.77314  79120.70256
# 2  Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# 3              Barnet  E09000003  93284.51832  93190.16963  92247.52435
# 4              Bexley  E09000004  64958.09036  64787.92069  64367.49344
#
# 0      1995-04      1995-05      1995-06      1995-07      1995-08  ...  \
# 0      1995-04      1995-05      1995-06      1995-07      1995-08  ...
# 1  77101.20804  84409.14932  94900.51244  110128.0423  112329.4376  ...
# 2  53133.50526  53042.24852  53700.34831  52113.12157  52232.19868  ...
# 3  90762.87492  90258.00033  90107.23471  91441.24768  92361.31512  ...
# 4  64277.66881  63997.13588  64252.32335  63722.70055  64432.60005  ...
#
# 0       2022-01       2022-02       2022-03       2022-04       2022-05  \
# ...

# %%
#Removing 1st row - contains data moved to column headers
properties = properties.drop(0)
properties.head()
# Out:
# 0          Unnamed: 0        NaN      1995-01      1995-02      1995-03  \
# 1      City of London  E09000001  91448.98487  82202.77314  79120.70256
# 2  Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# 3              Barnet  E09000003  93284.51832  93190.16963  92247.52435
# 4              Bexley  E09000004  64958.09036  64787.92069  64367.49344
# 5               Brent  E09000005  71306.56698  72022.26197  72015.76274
#
# 0      1995-04      1995-05      1995-06      1995-07      1995-08  ...  \
# 1  77101.20804  84409.14932  94900.51244  110128.0423  112329.4376  ...
# 2  53133.50526  53042.24852  53700.34831  52113.12157  52232.19868  ...
# 3  90762.87492  90258.00033  90107.23471  91441.24768  92361.31512  ...
# 4  64277.66881  63997.13588  64252.32335  63722.70055  64432.60005  ...
# 5  72965.63094  73704.04743  74310.48167  74127.03788   73547.0411  ...
#
# 0       2022-01       2022-02       2022-03       2022-04       2022-05  \
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
#Renaming 1st column containing London Borough names
properties = properties.rename(columns = {'Unnamed: 0' : 'London Borough'})
properties.head()
# Out:
# 0      London Borough        NaN      1995-01      1995-02      1995-03  \
# 1      City of London  E09000001  91448.98487  82202.77314  79120.70256
# 2  Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# 3              Barnet  E09000003  93284.51832  93190.16963  92247.52435
# 4              Bexley  E09000004  64958.09036  64787.92069  64367.49344
# 5               Brent  E09000005  71306.56698  72022.26197  72015.76274
#
# 0      1995-04      1995-05      1995-06      1995-07      1995-08  ...  \
# 1  77101.20804  84409.14932  94900.51244  110128.0423  112329.4376  ...
# 2  53133.50526  53042.24852  53700.34831  52113.12157  52232.19868  ...
# 3  90762.87492  90258.00033  90107.23471  91441.24768  92361.31512  ...
# 4  64277.66881  63997.13588  64252.32335  63722.70055  64432.60005  ...
# 5  72965.63094  73704.04743  74310.48167  74127.03788   73547.0411  ...
#
# 0       2022-01       2022-02       2022-03       2022-04       2022-05  \
# ...

# %%
#Renaming 2nd column with London Borough IDs (can't add pd.NaN to dictionary w/ column renames so instead renamed using index of column)
properties.columns.values[1] = 'ID'
properties.head()
# Out:
# 0      London Borough         ID      1995-01      1995-02      1995-03  \
# 1      City of London  E09000001  91448.98487  82202.77314  79120.70256
# 2  Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# 3              Barnet  E09000003  93284.51832  93190.16963  92247.52435
# 4              Bexley  E09000004  64958.09036  64787.92069  64367.49344
# 5               Brent  E09000005  71306.56698  72022.26197  72015.76274
#
# 0      1995-04      1995-05      1995-06      1995-07      1995-08  ...  \
# 1  77101.20804  84409.14932  94900.51244  110128.0423  112329.4376  ...
# 2  53133.50526  53042.24852  53700.34831  52113.12157  52232.19868  ...
# 3  90762.87492  90258.00033  90107.23471  91441.24768  92361.31512  ...
# 4  64277.66881  63997.13588  64252.32335  63722.70055  64432.60005  ...
# 5  72965.63094  73704.04743  74310.48167  74127.03788   73547.0411  ...
#
# 0       2022-01       2022-02       2022-03       2022-04       2022-05  \
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
#Using melt method to take wide Dataframe and put it into a more computer-friendly vertical format
#id_vars = columns that remain unpivoted, var_name = variable names that get unpivoted, value_name = values that get unpivoted
properties_melt = pd.melt(properties, id_vars = ['London Borough', 'ID'], var_name = 'Year_Month', value_name = 'Average_Home_Price')
properties_melt.head()
# Out:
#        London Borough         ID Year_Month Average_Home_Price
# 0      City of London  E09000001    1995-01        91448.98487
# 1  Barking & Dagenham  E09000002    1995-01         50460.2266
# 2              Barnet  E09000003    1995-01        93284.51832
# 3              Bexley  E09000004    1995-01        64958.09036
# 4               Brent  E09000005    1995-01        71306.56698

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
#Checking datatypes of each column
properties_melt.dtypes
# Out:
# London Borough        object
# ID                    object
# Year_Month            object
# Average_Home_Price    object
# dtype: object

# %%
#Changing Average_Home_Price column to from object to float datatype
properties_melt['Average_Home_Price'] = properties_melt['Average_Home_Price'].astype(float)
properties_melt.dtypes
# Out:
# London Borough         object
# ID                     object
# Year_Month             object
# Average_Home_Price    float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
#Prints concise summary of properties Dataframe
#Prints information about properties DataFrame including the index dtype and columns, non-null values and memory usage.
properties_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16032 entries, 0 to 16031
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   London Borough      16032 non-null  object
#  1   ID                  15030 non-null  object
#  2   Year_Month          16032 non-null  object
#  3   Average_Home_Price  15030 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 501.1+ KB

# %%
#Checking unique values in London Borough column, shows 48 values & there are only 32 London Boroughs
Borough_uniq = properties_melt['London Borough'].unique()
print(Borough_uniq)
len(Borough_uniq)
# Out:
# ['City of London' 'Barking & Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley'
#  'Camden' 'Croydon' 'Ealing' 'Enfield' 'Greenwich' 'Hackney'
#  'Hammersmith & Fulham' 'Haringey' 'Harrow' 'Havering' 'Hillingdon'
#  'Hounslow' 'Islington' 'Kensington & Chelsea' 'Kingston upon Thames'
#  'Lambeth' 'Lewisham' 'Merton' 'Newham' 'Redbridge' 'Richmond upon Thames'
#  'Southwark' 'Sutton' 'Tower Hamlets' 'Waltham Forest' 'Wandsworth'
#  'Westminster' 'Unnamed: 34' 'Inner London' 'Outer London' 'Unnamed: 37'
#  'NORTH EAST' 'NORTH WEST' 'YORKS & THE HUMBER' 'EAST MIDLANDS'
#  'WEST MIDLANDS' 'EAST OF ENGLAND' 'LONDON' 'SOUTH EAST' 'SOUTH WEST'
#  'Unnamed: 47' 'England']
# 48

# %%
#Removing rows that do not contain information about 32 relevant London Boroughs
drop_boroughs = ['City of London', 'Unnamed: 34', 'Inner London', 'Outer London', 'Unnamed: 37',
'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST',
 'Unnamed: 47', 'England']
properties_clean = properties_melt[~properties_melt['London Borough'].isin(drop_boroughs)]
properties_clean
# Out:
#            London Borough         ID Year_Month  Average_Home_Price
# 1      Barking & Dagenham  E09000002    1995-01         50460.22660
# 2                  Barnet  E09000003    1995-01         93284.51832
# 3                  Bexley  E09000004    1995-01         64958.09036
# 4                   Brent  E09000005    1995-01         71306.56698
# 5                 Bromley  E09000006    1995-01         81671.47692
# ...                   ...        ...        ...                 ...
# 16012              Sutton  E09000029    2022-10        445649.24841
# 16013       Tower Hamlets  E09000030    2022-10        484389.31536
# 16014      Waltham Forest  E09000031    2022-10        522646.34943
# 16015          Wandsworth  E09000032    2022-10        663273.01812
# 16016         Westminster  E09000033    2022-10        967166.29241
#
# [10688 rows x 4 columns]

# %%
#Checking for null values
properties_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10688 entries, 1 to 16016
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   London Borough      10688 non-null  object
#  1   ID                  10688 non-null  object
#  2   Year_Month          10688 non-null  object
#  3   Average_Home_Price  10688 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 417.5+ KB

# %%
#Checking that only relevant London Boroughs remain in this column
rel_Borough = properties_clean['London Borough'].unique()
print(rel_Borough)
len(rel_Borough)
# Out:
# ['Barking & Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley' 'Camden'
#  'Croydon' 'Ealing' 'Enfield' 'Greenwich' 'Hackney' 'Hammersmith & Fulham'
#  'Haringey' 'Harrow' 'Havering' 'Hillingdon' 'Hounslow' 'Islington'
#  'Kensington & Chelsea' 'Kingston upon Thames' 'Lambeth' 'Lewisham'
#  'Merton' 'Newham' 'Redbridge' 'Richmond upon Thames' 'Southwark' 'Sutton'
#  'Tower Hamlets' 'Waltham Forest' 'Wandsworth' 'Westminster']
# 32

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
#Filtering properties Dataframe for only Barnet London Borough
df_Barnet = properties_clean[properties_clean['London Borough'] == 'Barnet']
df_Barnet['London Borough'].unique()
# Out:
# array(['Barnet'], dtype=object)

# %%
#Ploting Average Home Prices over data timeframe for Barnet Borough
df_Barnet.plot(x = 'Year_Month', y = 'Average_Home_Price', rot = 45, kind = 'line', title = 'Average Home Prices for Barnet Borough')
# Out:
# <AxesSubplot:title={'center':'Average Home Prices for Barnet Borough'}, xlabel='Year_Month'>

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#Checking data type of Year_Month column
properties_clean['Year_Month'].dtype
# Out:
# dtype('O')

# %%
#Converting data type of Year_Month column to date time
properties_clean['Year_Month'] = pd.to_datetime(properties_clean['Year_Month'], format = '%Y/%m')
print(properties_clean.head())
properties_clean['Year_Month'].unique()
# Out:
#        London Borough         ID Year_Month  Average_Home_Price
# 1  Barking & Dagenham  E09000002 1995-01-01         50460.22660
# 2              Barnet  E09000003 1995-01-01         93284.51832
# 3              Bexley  E09000004 1995-01-01         64958.09036
# 4               Brent  E09000005 1995-01-01         71306.56698
# 5             Bromley  E09000006 1995-01-01         81671.47692
# C:\Users\jlmar\AppData\Local\Temp\ipykernel_34108\1826440637.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties_clean['Year_Month'] = pd.to_datetime(properties_clean['Year_Month'], format = '%Y/%m')
# array(['1995-01-01T00:00:00.000000000', '1995-02-01T00:00:00.000000000',
# ...

# %%
#Separating year and month of Year_Month and placing into separate columns
properties_clean = properties_clean.assign(Year = lambda x : (x['Year_Month'].dt.year))
properties_clean = properties_clean.assign(Month = lambda x : (x['Year_Month'].dt.month))
properties_clean = properties_clean.drop(columns = 'Year_Month')
properties_clean.head()
# Out:
#        London Borough         ID  Average_Home_Price  Year  Month
# 1  Barking & Dagenham  E09000002         50460.22660  1995      1
# 2              Barnet  E09000003         93284.51832  1995      1
# 3              Bexley  E09000004         64958.09036  1995      1
# 4               Brent  E09000005         71306.56698  1995      1
# 5             Bromley  E09000006         81671.47692  1995      1

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
#Creating function to calculate ratio of average home price in 1998 : average home price in 2018 for each borough
def borough_home_price(borough):
    filter_df = properties_clean[properties_clean['London Borough'] == borough]
    dates_1998 = ['1998-01', '1998-02', '1998-03', '1998-04', '1998-05', '1998-06','1998-07', '1998-08', '1998-09', '1998-10', '1998-11', '1998-12']
    dates_2018 = ['2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06','2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12']
    df_1998 = filter_df[filter_df['Year_Month'].isin(dates_1998)]
    df_2018 = filter_df[filter_df['Year_Month'].isin(dates_2018)]
    mean_1998 = df_1998['Average_Home_Price'].mean()
    mean_2018 = df_2018['Average_Home_Price'].mean()
    ratio = round((mean_1998/mean_2018), 6)
    return ratio

# %%
#Getting list of 32 London Boroughs
London_Borough_list = properties_clean['London Borough'].unique()
print(London_Borough_list)
# Out:
# ['Barking & Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley' 'Camden'
#  'Croydon' 'Ealing' 'Enfield' 'Greenwich' 'Hackney' 'Hammersmith & Fulham'
#  'Haringey' 'Harrow' 'Havering' 'Hillingdon' 'Hounslow' 'Islington'
#  'Kensington & Chelsea' 'Kingston upon Thames' 'Lambeth' 'Lewisham'
#  'Merton' 'Newham' 'Redbridge' 'Richmond upon Thames' 'Southwark' 'Sutton'
#  'Tower Hamlets' 'Waltham Forest' 'Wandsworth' 'Westminster']

# %%
#Creating dictionary of borough as key and ratio of average home price in 1998 : average home price in 2018 as value
dict = {}
for borough in London_Borough_list:
    dict[borough] = borough_home_price(borough)
print(dict)
# Out:
# {'Barking & Dagenham': 0.204223, 'Barnet': 0.229453, 'Bexley': 0.235351, 'Brent': 0.204309, 'Bromley': 0.244213, 'Camden': 0.20262, 'Croydon': 0.238033, 'Ealing': 0.23194, 'Enfield': 0.234551, 'Greenwich': 0.20995, 'Hackney': 0.161335, 'Hammersmith & Fulham': 0.241674, 'Haringey': 0.194756, 'Harrow': 0.246354, 'Havering': 0.231202, 'Hillingdon': 0.23808, 'Hounslow': 0.251483, 'Islington': 0.206439, 'Kensington & Chelsea': 0.196755, 'Kingston upon Thames': 0.234162, 'Lambeth': 0.201704, 'Lewisham': 0.183512, 'Merton': 0.210914, 'Newham': 0.188488, 'Redbridge': 0.223655, 'Richmond upon Thames': 0.249678, 'Southwark': 0.181275, 'Sutton': 0.242806, 'Tower Hamlets': 0.216137, 'Waltham Forest': 0.171387, 'Wandsworth': 0.210185, 'Westminster': 0.186791}

# %%
#Creating bar plot of ratio of home price 1998 : 2018 t0 borough to identify borough with greatest increase in home price
boroughs = list(dict.keys())
home_price_ratio = list(dict.values())
plt.bar(range(len(dict)), home_price_ratio, tick_label = boroughs)
plt.xticks(rotation = 90, fontsize = 10)
plt.ylabel('Avg Home Price 1998 : Avg Home Price 2018')
plt.show()

# %%
sorted_dict = sorted(dict.items(), key = lambda x:x[1])
print(sorted_dict)
# Out:
# [('Hackney', 0.161335), ('Waltham Forest', 0.171387), ('Southwark', 0.181275), ('Lewisham', 0.183512), ('Westminster', 0.186791), ('Newham', 0.188488), ('Haringey', 0.194756), ('Kensington & Chelsea', 0.196755), ('Lambeth', 0.201704), ('Camden', 0.20262), ('Barking & Dagenham', 0.204223), ('Brent', 0.204309), ('Islington', 0.206439), ('Greenwich', 0.20995), ('Wandsworth', 0.210185), ('Merton', 0.210914), ('Tower Hamlets', 0.216137), ('Redbridge', 0.223655), ('Barnet', 0.229453), ('Havering', 0.231202), ('Ealing', 0.23194), ('Kingston upon Thames', 0.234162), ('Enfield', 0.234551), ('Bexley', 0.235351), ('Croydon', 0.238033), ('Hillingdon', 0.23808), ('Hammersmith & Fulham', 0.241674), ('Sutton', 0.242806), ('Bromley', 0.244213), ('Harrow', 0.246354), ('Richmond upon Thames', 0.249678), ('Hounslow', 0.251483)]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ### My Conclusion:
# Based on the calculation of the ratio - average home price in 1998 to average home price in 2018,
# the borough with the lowest value ratio will have seen the greatest increase in average home prices from 1998 to 2018.
# From the bar plot above and sorting of the borough : ratio key, value dictionary, the lowest ratio is in Hackney.
# The Hackney London borough saw the greatest increase in average home prices from 1998 to 2018.
